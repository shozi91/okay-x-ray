# %%
# !pip install awscli
# Out:
# Requirement already satisfied: awscli in /usr/local/lib/python3.6/dist-packages (1.18.105)
# Requirement already satisfied: PyYAML<5.4,>=3.10 in /usr/local/lib/python3.6/dist-packages (from awscli) (3.13)
# Requirement already satisfied: botocore==1.17.28 in /usr/local/lib/python3.6/dist-packages (from awscli) (1.17.28)
# Requirement already satisfied: colorama<0.4.4,>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from awscli) (0.4.3)
# Requirement already satisfied: rsa<=4.5.0,>=3.1.2 in /usr/local/lib/python3.6/dist-packages (from awscli) (4.5)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from awscli) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from awscli) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore==1.17.28->awscli) (2.8.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from botocore==1.17.28->awscli) (0.10.0)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from botocore==1.17.28->awscli) (1.24.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<=4.5.0,>=3.1.2->awscli) (0.4.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.17.28->awscli) (1.15.0)

# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (1.14.24)
# Requirement already satisfied: botocore<1.18.0,>=1.17.24 in /usr/local/lib/python3.6/dist-packages (from boto3) (1.17.28)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3) (0.10.0)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3) (1.24.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.18.0,>=1.17.24->boto3) (1.15.0)

# %%
# !aws configure
# Out:
# AWS Access Key ID [None]: AKIAWFTKXIO53V4KFS7P
# AWS Secret Access Key [None]: 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
# Default region name [None]: us-east-2
# Default output format [None]:

# %%
# !aws s3 ls
# Out:
# 2020-07-25 14:24:02 okayxray

# %%
import boto3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from sklearn.metrics import confusion_matrix

from keras.preprocessing.image import ImageDataGenerator, array_to_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.layers import Dropout
from tensorflow import keras
#from keras.layers import BatchNormalization

s3 = boto3.client('s3') #low-level functional API
s3.download_file(Bucket='okayxray',Key='model/ver3_model_softmax_3L64u_3Lnode_5epochs.h5',Filename= "/tmp/ver3_model_softmax_3L64u_3Lnode_5epochs.h5")

# %%
model = keras.models.load_model("/tmp/ver3_model_softmax_3L64u_3Lnode_5epochs.h5")

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 498, 498, 64)      640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 249, 249, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 249, 249, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 247, 247, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 123, 123, 64)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 123, 123, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 121, 121, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 60, 60, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 60, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 230400)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               29491328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 29,590,722
# Trainable params: 29,590,722
# Non-trainable params: 0
# _________________________________________________________________
